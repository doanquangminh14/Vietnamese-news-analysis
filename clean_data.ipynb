# %%
import pandas as pd
df = pd.read_csv('vnexpress_data_clean.csv')
df
# Out:
#                                                 Title  \
# 0   hlv kim sang sik   tôi thành công vì được lòng...
# 1            ronaldo nôn ói ở trận thắng của al nassr
# 2   vì sao vff không chọn hlv ngoại cho đội tuyển nữ
# 3   arsenal  man city có thể đá play off ở ngoại h...
# 4   neville   arsenal phải cân bằng cảm xúc khi đố...
# ..                                                ...
# 78          vị khách đặc biệt đến thăm tuyển malaysia
# 79    xuân son sẵn sàng trước ngày đại chiến malaysia
# 80            audition vào chung kết game awards 2026
# 81         romario bị tố phản bội bạn gái kém 35 tuổi
# 82  ngôi sao nba và chuyện khởi nghiệp từ tiền gửi...
#
#                                                  Link  Category  \
# 0   https://vnexpress.net/hlv-kim-sang-sik-toi-tha...  Thể thao
# 1   https://vnexpress.net/ronaldo-non-oi-o-tran-th...  Thể thao
# 2   https://vnexpress.net/vi-sao-vff-khong-chon-hl...  Thể thao
# ...
