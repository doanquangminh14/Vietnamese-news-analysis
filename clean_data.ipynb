# %%
import pandas as pd
df = pd.read_csv('vnexpress_data_clean.csv')
df
# Out:
#                                                  Title  \
# 0    HLV Kim Sang-sik: 'Tôi thành công vì được lòng...
# 1    Vì sao VFF không chọn HLV ngoại cho đội tuyển nữ?
# 2    Arsenal, Man City có thể đá play-off ở Ngoại h...
# 3    Neville: 'Arsenal phải cân bằng cảm xúc khi đố...
# 4    Henry: 'Real phải nếm thứ thuốc độc do chính h...
# ..                                                 ...
# 237  Vị trí nào cho McIlroy trong ngôi đền huyền th...
# 238  Cua-rơ Việt kiều thắng chặng ở giải xe đạp xuy...
# 239  Cựu thủ môn Arsenal và Liverpool thiệt mạng vì...
# 240                Hậu vệ Vũ Văn Thanh cầu hôn bạn gái
# 241         Romario bị tố phản bội bạn gái kém 35 tuổi
#
#                                                   Link  Category  \
# 0    https://vnexpress.net/hlv-kim-sang-sik-toi-tha...  Thể thao
# 1    https://vnexpress.net/vi-sao-vff-khong-chon-hl...  Thể thao
# 2    https://vnexpress.net/arsenal-man-city-co-the-...  Thể thao
# ...
